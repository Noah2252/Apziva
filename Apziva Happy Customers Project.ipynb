# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import Sequential
from keras.layers import Dense, Activation
from sklearn.linear_model import LogisticRegressionCV

# %%
HappinessSurvey2020 = pd.read_csv("ACME-HappinessSurvey2020.csv")

# %%
HappinessSurvey2020
# Out:
#      Y  X1  X2  X3  X4  X5  X6
# 0    0   3   3   3   4   2   4
# 1    0   3   2   3   5   4   3
# 2    1   5   3   3   3   3   5
# 3    0   5   4   3   3   3   5
# 4    0   5   4   3   3   3   5
# 5    1   5   5   3   5   5   5
# 6    0   3   1   2   2   1   3
# 7    1   5   4   4   4   4   5
# 8    0   4   1   4   4   4   4
# 9    0   4   4   4   2   5   5
# 10   0   3   2   3   3   2   3
# 11   0   4   4   3   4   4   4
# 12   1   5   2   4   5   5   5
# 13   0   4   2   4   5   4   3
# 14   0   4   1   3   3   4   3
# 15   1   3   2   4   3   4   4
# 16   0   5   3   4   5   4   5
# 17   1   5   1   4   3   4   5
# 18   0   5   1   2   4   4   5
# 19   0   4   2   4   4   4   4
# 20   1   4   2   3   3   4   4
# 21   0   4   3   5   5   5   4
# 22   0   4   3   5   5   5   4
# 23   1   5   1   2   5   2   4
# 24   1   4   3   3   3   3   4
# 25   0   3   4   3   3   2   3
# 26   1   3   3   3   5   5   5
# 27   1   3   3   1   3   3   4
# 28   1   3   3   1   3   3   4
# 29   1   5   3   3   3   5   3
# ..  ..  ..  ..  ..  ..  ..  ..
# 96   0   4   4   3   4   3   3
# 97   1   5   4   5   4   5   4
# 98   1   4   2   3   4   3   3
# 99   0   3   3   2   4   4   4
# 100  1   5   2   2   4   5   5
# 101  1   5   3   4   3   4   3
# 102  0   5   2   3   3   3   5
# 103  1   4   3   4   4   3   4
# 104  0   4   1   3   5   3   5
# 105  1   5   1   4   3   5   5
# 106  1   5   1   5   3   5   5
# 107  0   4   2   4   4   4   4
# 108  0   5   2   4   4   5   5
# 109  1   5   3   4   4   4   4
# 110  0   5   3   3   4   4   5
# 111  0   5   3   3   4   4   4
# 112  0   4   1   3   3   3   4
# 113  0   5   1   4   4   4   5
# 114  0   5   2   2   4   4   5
# 115  0   5   3   5   4   5   5
# 116  1   3   4   4   5   1   3
# 117  1   5   1   5   5   5   5
# 118  1   4   3   3   4   4   4
# 119  1   5   5   1   1   5   1
# 120  0   4   4   4   4   1   3
# 121  1   5   2   3   4   4   3
# 122  1   5   2   3   4   2   5
# 123  1   5   3   3   4   4   5
# 124  0   4   3   3   4   4   5
# 125  0   5   3   2   5   5   5
#
# [126 rows x 7 columns]

# %%
x_data = HappinessSurvey2020[['X1', 'X2', 'X3','X4','X5','X6']]
y_data = HappinessSurvey2020['Y']

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.1)

# %%
clf = SVC(kernel='linear',probability=True)
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.6923076923076923

# %%
logReg = LogisticRegression()
logReg.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
logregpred = logReg.predict(X_test)
accuracy_score(y_test,logregpred)
# Out:
# 0.6153846153846154

# %%
logRegCV = LogisticRegressionCV()
logRegCV.fit(X_train,y_train)
# Out:
# LogisticRegressionCV(Cs=10, class_weight=None, cv=None, dual=False,
#            fit_intercept=True, intercept_scaling=1.0, max_iter=100,
#            multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#            refit=True, scoring=None, solver='lbfgs', tol=0.0001, verbose=0)

# %%
logregCVpred = logRegCV.predict(X_test)
accuracy_score(y_test,logregCVpred)
# Out:
# 0.6153846153846154

# %%
ranfor1 = RandomForestClassifier(n_estimators= 1000, max_depth=2)
ranfor1.fit(X_train,y_train)
ranfor1pred = ranfor1.predict(X_test)
accuracy_score(y_test,ranfor1pred)
# Out:
# 0.5384615384615384

# %%
neigh = KNeighborsClassifier(n_neighbors=2)
neigh.fit(X_train,y_train)
neighpred = neigh.predict(X_test)
accuracy_score(y_test,neighpred)
# Out:
# 0.6153846153846154

# %%
def build_model():
    model = Sequential()
    model.add(Dense(500, activation='relu', input_dim=6))
    model.add(Dense(100, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(2, activation='softmax'))
    
    model.compile(optimizer='adam', 
                  loss='categorical_crossentropy', 
                  metrics=['accuracy'])
    
    
    return model

Kclf = KerasClassifier(build_model, epochs=10)

# %%
Kclf.fit(X_train,y_train)
Kclfpred = Kclf.predict(X_test)
# Out:
# Epoch 1/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7257 - accuracy: 0.5176
# Epoch 2/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6846 - accuracy: 0.5818
# Epoch 3/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6846 - accuracy: 0.5351
# Epoch 4/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6770 - accuracy: 0.5532
# Epoch 5/10
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6696 - accuracy: 0.5588
# Epoch 6/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6602 - accuracy: 0.6276
# Epoch 7/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6647 - accuracy: 0.5905
# Epoch 8/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6695 - accuracy: 0.5768
# Epoch 9/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6699 - accuracy: 0.5651
# Epoch 10/10
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6499 - accuracy: 0.6040
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
accuracy_score(y_test,Kclfpred)
# Out:
# 0.5384615384615384
